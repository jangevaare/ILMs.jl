# %% [markdown]
# Load the ilmtools package...

# %%
include("ilmtools.jl")
# Out:
# spatial_states (generic function with 1 method)

# %% [markdown]
# Generate a population from a bi-variate normal distribution...

# %%
pop_db1 = create_pop_db(50, MvNormal(eye(2).*4))
# Out:
# 50x3 DataFrame
# | Row | ind_id | x          | y          |
# |-----|--------|------------|------------|
# | 1   | 1      | 2.31021    | 4.29575    |
# | 2   | 2      | 2.94056    | -1.75263   |
# | 3   | 3      | -5.79064   | 1.53534    |
# | 4   | 4      | -0.947864  | -1.30627   |
# | 5   | 5      | -0.132804  | 1.03629    |
# | 6   | 6      | -0.0800773 | -2.6874    |
# | 7   | 7      | 3.26677    | -2.74528   |
# | 8   | 8      | -0.18268   | 0.164676   |
# | 9   | 9      | -1.52577   | -1.04551   |
# | 10  | 10     | 1.13462    | 1.05259    |
# | 11  | 11     | 1.69886    | -0.0458365 |
# ⋮
# | 39  | 39     | -0.723736  | 1.56136    |
# | 40  | 40     | 2.74841    | -4.30637   |
# | 41  | 41     | -1.67141   | -1.14615   |
# | 42  | 42     | -1.01261   | 1.31769    |
# | 43  | 43     | 1.46984    | 1.61846    |
# | 44  | 44     | -0.469204  | -2.83755   |
# | 45  | 45     | -1.98987   | -1.43824   |
# | 46  | 46     | 0.248134   | 1.56641    |
# ...

# %%
#TEMP
alpha=1
beta=15
gamma=5
distance_mat_alphabeta = dist_ab_mtx(create_dist_mtx(pop_db1), alpha, beta)
evdb = create_event_db(pop_db1, "continuous", gamma)
initial_infect(evdb, gamma)
for i = 1:30
    infect_recover(distance_mat_alphabeta, evdb, maximum(evdb.events[3]), gamma)
end
evdb.events[:,3]
# Out:
# 50-element DataArray{Float64,1}:
#  NaN
#    3.19177
#  NaN
#    1.0
#    2.60986
#    3.27269
#  NaN
#    2.60952
#    1.0
#    2.77862
#    2.94129
#  NaN
#  NaN
#    ⋮
#    2.62202
#  NaN
#    1.0
#    2.62202
#    2.77979
#    3.2727
#    1.00001
#    2.61062
#  NaN
#    2.94122
#    2.94122
#  NaN

# %% [markdown]
# Generate the initial infection and propagate infection through population (SIR model) in continuous time with parameters alpha=1, beta=15, gamma=5

# %%
evdb = infect_recover_loop(pop_db1, "continuous", "SIR", 1, 5, 10)
# Out:
# arrays could not be broadcast to a common size
# while loading In[10], in expression starting on line 1
#
#  in broadcast_shape at broadcast.jl:40
#  in infect_recover at /Users/justin/Dropbox/Projects/ilmtools/events.jl:194
#  in infect_recover_loop at /Users/justin/Dropbox/Projects/ilmtools/events.jl:248

# %% [markdown]
# Visualize infection (susceptible, infected, and recovered) through time

# %%
evseries = state_timeseries(evdb)
plot(evseries, x="time", y="S", Geom.line)
# Out:
# Plot(...)

# %%
plot(evseries, x="time", y="I", Geom.line)
# Out:
# Plot(...)

# %%
#plot(evseries, x="time", y="R", Geom.line)

# %% [markdown]
# Spatial plots...

# %%
state_db=spatial_states(pop_db1, evdb, evdb.event_times[10])
plot(state_db, x="x", y="y", Geom.point, color="state")
# Out:
# Plot(...)

# %%
evdb.event_time
# Out:
# evdb not defined
# while loading In[8], in expression starting on line 1
