# %% [markdown]
# Load the ilmtools package...

# %%
include("ilmtools.jl")
# Out:
# state_animation (generic function with 1 method)

# %% [markdown]
# Generate a population from a bi-variate normal distribution...

# %%
pop_db1 = create_pop_db(100, MvNormal(eye(2).*4))
# Out:
# 100x3 DataFrame
# | Row | ind_id | x           | y         |
# |-----|--------|-------------|-----------|
# | 1   | 1      | -3.59219    | -0.179345 |
# | 2   | 2      | -3.36171    | 0.5833    |
# | 3   | 3      | -1.8377     | 2.52144   |
# | 4   | 4      | 1.34002     | 1.70846   |
# | 5   | 5      | 1.18219     | 0.247721  |
# | 6   | 6      | 1.09014     | 1.8318    |
# | 7   | 7      | -3.03469    | 1.12      |
# | 8   | 8      | -0.516288   | 1.99127   |
# | 9   | 9      | 2.08653     | -0.330611 |
# | 10  | 10     | 2.63646     | -0.192232 |
# | 11  | 11     | -0.876666   | -1.08477  |
# ⋮
# | 89  | 89     | 6.83572     | 0.408877  |
# | 90  | 90     | -0.00561592 | -3.07033  |
# | 91  | 91     | 2.5112      | -2.35332  |
# | 92  | 92     | -0.498047   | -2.09744  |
# | 93  | 93     | -0.325131   | -0.539511 |
# | 94  | 94     | 1.79301     | 0.322945  |
# | 95  | 95     | -2.24878    | -1.55034  |
# | 96  | 96     | 0.853918    | 0.749553  |
# | 97  | 97     | -2.72734    | -3.54774  |
# | 98  | 98     | 1.5018      | 2.22966   |
# | 99  | 99     | -2.54683    | -0.835394 |
# | 100 | 100    | -0.232687   | -0.765526 |

# %% [markdown]
# Generate the initial infection and propagate infection through population (SIR model) in continuous time with parameters $\alpha=1, \beta=15, \gamma=5$

# %%
evdb = infect_recover_loop(pop_db1, "continuous", "SIR", 1, 5, 10)
# Out:
# edb(100x4 DataFrame
# | Row | ind_id | s | i       | r       |
# |-----|--------|---|---------|---------|
# | 1   | 1      | 0 | 1.52934 | 5.56709 |
# | 2   | 2      | 0 | 1.51993 | 3.81208 |
# | 3   | 3      | 0 | 1.46904 | 18.7364 |
# | 4   | 4      | 0 | 1.30586 | 9.6819  |
# | 5   | 5      | 0 | 1.2619  | 7.67018 |
# | 6   | 6      | 0 | 1.30736 | 12.9642 |
# | 7   | 7      | 0 | 1.67709 | 14.6451 |
# | 8   | 8      | 0 | 1.34212 | 29.0028 |
# | 9   | 9      | 0 | 1.24726 | 4.09101 |
# | 10  | 10     | 0 | 1.23011 | 2.93796 |
# | 11  | 11     | 0 | 1.27431 | 17.7791 |
# ⋮
# | 89  | 89     | 0 | NaN     | NaN     |
# | 90  | 90     | 0 | 1.29924 | 25.8587 |
# | 91  | 91     | 0 | 1.15836 | 34.3606 |
# | 92  | 92     | 0 | 1.26713 | 1.96357 |
# | 93  | 93     | 0 | 1.26836 | 9.94684 |
# | 94  | 94     | 0 | 1.26434 | 2.97759 |
# | 95  | 95     | 0 | 1.35199 | 2.8097  |
# | 96  | 96     | 0 | 1.26365 | 21.5613 |
# | 97  | 97     | 0 | 5.42574 | 15.3243 |
# | 98  | 98     | 0 | 1.31292 | 19.581  |
# | 99  | 99     | 0 | 1.31623 | 5.00286 |
# | 100 | 100    | 0 | 1.26839 | 14.533  |,[1.0,1.00576,1.15836,1.16297,1.22674,1.22683,1.22698,1.23011,1.23096,1.24066  …  29.0028,29.1418,29.6123,30.3713,34.3606,36.2793,36.3283,47.3093,Inf,Inf],"continuous")

# %% [markdown]
# Visualize infection (susceptible, infected, and recovered) through time

# %%
evseries = state_timeseries(evdb)
plot(evseries, x="time", y="S", Geom.line)
# Out:
# Plot(...)

# %%
plot(evseries, x="time", y="I", Geom.line)
# Out:
# Plot(...)

# %%
plot(evseries, x="time", y="R", Geom.line)
# Out:
# Plot(...)

# %% [markdown]
# Spatial plots with a time window of 0.5

# %%
state_animation(0.5, evdb, pop_db1)
# Out:
# Slider{Float64}([Input{Float64}] 24.5,"time",24.5,1.0:0.5:48.0)
# Plot(...)
