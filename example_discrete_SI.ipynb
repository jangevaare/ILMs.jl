# %% [markdown]
# Load the ilmtools package...

# %%
include("ilmtools.jl")
# Out:
# state_animation (generic function with 1 method)

# %% [markdown]
# Generate a population with a bivariate uniform spatial distribution (over a 25 by 25 unit area)

# %%
pop_db1 = create_pop_db_univariates(625, Uniform(0,25), Uniform(0,25))
# Out:
# 625x3 DataFrame
# | Row | ind_id | x        | y       |
# |-----|--------|----------|---------|
# | 1   | 1      | 9.10208  | 2.58046 |
# | 2   | 2      | 20.7448  | 5.5795  |
# | 3   | 3      | 4.12284  | 20.7895 |
# | 4   | 4      | 1.17377  | 14.1248 |
# | 5   | 5      | 24.3204  | 21.5414 |
# | 6   | 6      | 7.95294  | 7.79026 |
# | 7   | 7      | 16.0495  | 20.3465 |
# | 8   | 8      | 17.4018  | 8.53333 |
# | 9   | 9      | 16.8409  | 22.7239 |
# | 10  | 10     | 14.1153  | 18.4567 |
# | 11  | 11     | 1.25906  | 1.42556 |
# ⋮
# | 614 | 614    | 12.7318  | 18.0951 |
# | 615 | 615    | 3.53157  | 13.9439 |
# | 616 | 616    | 0.998269 | 4.44306 |
# | 617 | 617    | 11.5023  | 2.45321 |
# | 618 | 618    | 20.4797  | 14.8846 |
# | 619 | 619    | 20.9658  | 21.6906 |
# | 620 | 620    | 4.24754  | 5.50179 |
# | 621 | 621    | 20.4428  | 22.5478 |
# | 622 | 622    | 22.6413  | 20.6869 |
# | 623 | 623    | 18.6086  | 21.9499 |
# | 624 | 624    | 11.2612  | 1.17457 |
# | 625 | 625    | 15.4409  | 24.7571 |

# %%
alpha=2
beta=6
gamma=Inf
distance_mat_alphabeta = dist_ab_mtx(create_dist_mtx(pop_db1), alpha, beta)
event_db = create_event_db(pop_db1, "discrete", gamma)
initial_infect!(event_db, gamma)
for t = 2:15
    infect_recover!(distance_mat_alphabeta, event_db, t, gamma)
end
state_animation(1, event_db, pop_db1)
# Out:
# Slider{Float64}([Input{Float64}] 8.0,"time",8.0,1.0:1.0:16.0)
# Plot(...)

# %% [markdown]
# Generate the initial infection and propagate infection through population (SI model) in discrete time with parameters $\alpha=2$ and $\beta=6$

# %%
evdb = infect_recover_loop(pop_db1, "discrete", "SI", 5, 2, Inf)

# %% [markdown]
# Visualize infection (susceptible and infected) through time

# %%
evseries = state_timeseries(evdb)
plot(evseries, x="time", y="S", Geom.line)
# Out:
# state_timeseries not defined
# while loading In[5], in expression starting on line 1

# %%
plot(evseries, x="time", y="I", Geom.line)
# Out:
# evseries not defined
# while loading In[6], in expression starting on line 1

# %% [markdown]
# Spatial plots...

# %%
state_animation(1, evdb, pop_db1)
# Out:
# state_animation not defined
# while loading In[7], in expression starting on line 1
